# %%
import pandas as pd


pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)


df = pd.read_parquet("results.parquet", engine="fastparquet")
df.T
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       4 pd.set_option('display.width', None)
#       5 pd.set_option('display.max_colwidth', None)
#       6
#       7
# ----> 8 df = pd.read_parquet("results.parquet", engine="fastparquet")
#       9 df.T
#
# File ~/Documents/MemorabilityEmotions/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:671, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     668 impl = get_engine(engine)
#     669 check_dtype_backend(dtype_backend)
# --> 671 return impl.read(
#     672     path,
#     673     columns=columns,
#     674     filters=filters,
#     675     storage_options=storage_options,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     to_pandas_kwargs=to_pandas_kwargs,
#     679     **kwargs,
# ...

# %%
df.shape
# Out:
# (9, 7)

# %%
16000*40
# Out:
# 640000

# %%
df[["image", "model", "emotion", "description"]].sort_values("image").head(20)
# Out:
#         image      model    emotion  \
# 0   10002.jpg      llava       fear
# 1   10015.jpg      llava  happiness
# 2    1004.jpg      llava    sadness
# 3   10062.jpg      llava  happiness
# 4   10108.jpg      llava  happiness
# 5   10153.jpg      llava    sadness
# 6   10153.jpg  gemma3:4b    sadness
# 7   10157.jpg      llava       fear
# 8   10157.jpg  gemma3:4b       fear
# 9   10172.jpg      llava   surprise
# 10  10172.jpg  gemma3:4b       fear
# 11  10197.jpg      llava   surprise
# 12  10197.jpg  gemma3:4b       fear
# 13  10203.jpg      llava   surprise
# 14  10203.jpg  gemma3:4b       fear
#
# ...

# %%
file = "llm_captions_results/batch_0000.parquet"

# %%
df = pd.read_parquet(file, engine="fastparquet")
df.T
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0    \
# image                                                                                                                                                                                                                                                                                                                                                                                                                                                                          10002.jpg
# ...

# %%
df.shape
# Out:
# (500, 7)

# %%
df.emotion.value_counts()
# Out:
# emotion
# surprise     137
# happiness    122
# fear         113
# sadness       98
# disgust        7
# anger          2
# Name: count, dtype: int64
