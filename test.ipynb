# %%
import pandas as pd


pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)


df = pd.read_parquet("results.parquet", engine="fastparquet")
df.head().T
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0  \
# ...

# %%
16000*40
# Out:
# 640000

# %%
df[["model", "emotion", "description"]].head(10)
# Out:
#        model   emotion  \
# 0  llava:13b      fear
# 1      llava      fear
# 2  moondream  surprise
# 3  llava:13b  surprise
# 4      llava  surprise
# 5  moondream  surprise
# 6  llava:13b   sadness
# 7      llava      fear
# 8  moondream      None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               description
# ...
